# %%
import sys
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import urllib
from threading import Thread
from queue import Queue
import math
import requests
import time 
from datetime import timedelta
import pickle
from datetime import datetime

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('correct3.csv', index_col=0, encoding="utf-8", delimiter=",")
df.head()
# Out:
#         sizeOriginal  sizeDaff  evolution   patch  quality  numberOfVersions  \
# folder
# 31           6936693    126897       3896   10388     3840                92
# 74            166816    165803        152     109      106                66
# 98          14609270    921000      20471  237332    10327                56
# 516          5524334    589086       2023   10137     1452                42
# 519          3235981    286304       1292    6907      811                44
#
#         originalRows  originalColumns  addedRows  deletedRows  modifiedRows  \
# folder
# 31              1320                2   0.005097     0.000008      0.000634
# 74                18               12   0.005892     0.001684      1.194444
# 98              1858               18   0.000951     0.000048      0.023643
# 516              157               22   0.009099     0.001365      0.000000
# 519               64               13   0.154830     0.008168      0.067827
#
#         addedColumns  deletedColumns  modifiedColumns  totalChanged  \
# folder
# 31          0.000000        0.000000              0.0          1317
# 74          0.002525        0.002525              0.0       1631085
# 98          0.001984        0.000000              0.0      14642613
# 516         0.000000        0.000000              0.0          1494
# 519         0.000000        0.000000              0.0          6214
#
#         changedCells
# folder
# 31          0.005422
# 74        114.413931
# 98          7.818300
# 516         0.010299
# 519         0.169744

# %%
del df['modifiedColumns']
del df['totalChanged']

# %%
df.describe()
# Out:
#        sizeOriginal      sizeDaff     evolution         patch        quality  \
# count  7.260000e+02  7.260000e+02  7.260000e+02  7.260000e+02     726.000000
# mean   7.080259e+05  2.922477e+05  6.247583e+03  8.964331e+03    1190.757576
# std    1.904106e+06  9.737492e+05  9.996206e+04  6.105751e+04    7186.780706
# min    4.940000e+02  1.069000e+03  6.000000e+00  5.000000e+00       4.000000
# 25%    7.775675e+04  6.323375e+04  3.117500e+02  6.325000e+01     167.250000
# 50%    1.864425e+05  1.110580e+05  6.730000e+02  1.320000e+02     324.000000
# 75%    3.836960e+05  2.265822e+05  1.106000e+03  3.197500e+02     535.750000
# max    1.889952e+07  1.423151e+07  2.676666e+06  1.005401e+06  123843.000000
#
#        numberOfVersions  originalRows  originalColumns   addedRows  \
# count        726.000000    726.000000       726.000000  726.000000
# mean          17.826446    431.234160         5.404959    1.852942
# std            6.179848   1596.233829         8.479829   21.371108
# min            8.000000      1.000000         1.000000    0.000000
# 25%           14.000000     24.000000         1.000000    0.028640
# 50%           18.000000     74.000000         1.000000    0.220709
# 75%           21.000000    455.000000         6.000000    0.771335
# max           92.000000  29225.000000        51.000000  572.250000
#
#        deletedRows  modifiedRows  addedColumns  deletedColumns   changedCells
# count   726.000000    726.000000    726.000000      726.000000     726.000000
# mean      0.792824      0.088197      0.225498        0.224304    1663.955061
# std       2.021257      0.802850      0.286035        0.286892   29564.600994
# min       0.000000      0.000000      0.000000        0.000000       0.000545
# 25%       0.008388      0.000000      0.009259        0.000000       3.746759
# 50%       0.209025      0.000000      0.229021        0.229021     100.296340
# 75%       0.523821      0.003696      0.362727        0.362727     361.371122
# max      31.408696     19.774510      6.187500        6.187500  795793.332881

# %%
df = df.rename(columns={'evolution': 'comparisonTime', 'patch': 'patchingTime', 'quality':'validationTime'})

# %%
df.head()
# Out:
#         sizeOriginal  sizeDaff  comparisonTime  patchingTime  validationTime  \
# folder
# 31           6936693    126897            3896         10388            3840
# 74            166816    165803             152           109             106
# 98          14609270    921000           20471        237332           10327
# 516          5524334    589086            2023         10137            1452
# 519          3235981    286304            1292          6907             811
#
#         numberOfVersions  originalRows  originalColumns  addedRows  \
# folder
# 31                    92          1320                2   0.005097
# 74                    66            18               12   0.005892
# 98                    56          1858               18   0.000951
# 516                   42           157               22   0.009099
# 519                   44            64               13   0.154830
#
#         deletedRows  modifiedRows  addedColumns  deletedColumns  changedCells
# folder
# 31         0.000008      0.000634      0.000000        0.000000      0.005422
# 74         0.001684      1.194444      0.002525        0.002525    114.413931
# 98         0.000048      0.023643      0.001984        0.000000      7.818300
# 516        0.001365      0.000000      0.000000        0.000000      0.010299
# 519        0.008168      0.067827      0.000000        0.000000      0.169744

# %%
df['difference'] = df['sizeDaff'] / df['sizeOriginal']

# %%
df.head()
# Out:
#         sizeOriginal  sizeDaff  comparisonTime  patchingTime  validationTime  \
# folder
# 31           6936693    126897            3896         10388            3840
# 74            166816    165803             152           109             106
# 98          14609270    921000           20471        237332           10327
# 516          5524334    589086            2023         10137            1452
# 519          3235981    286304            1292          6907             811
#
#         numberOfVersions  originalRows  originalColumns  addedRows  \
# folder
# 31                    92          1320                2   0.005097
# 74                    66            18               12   0.005892
# 98                    56          1858               18   0.000951
# 516                   42           157               22   0.009099
# 519                   44            64               13   0.154830
#
#         deletedRows  modifiedRows  addedColumns  deletedColumns  changedCells  \
# folder
# 31         0.000008      0.000634      0.000000        0.000000      0.005422
# 74         0.001684      1.194444      0.002525        0.002525    114.413931
# 98         0.000048      0.023643      0.001984        0.000000      7.818300
# 516        0.001365      0.000000      0.000000        0.000000      0.010299
# 519        0.008168      0.067827      0.000000        0.000000      0.169744
#
#         difference
# folder
# 31        0.018294
# 74        0.993927
# 98        0.063042
# 516       0.106635
# 519       0.088475

# %%
df.corr()
# Out:
#                   sizeOriginal  sizeDaff  comparisonTime  patchingTime  \
# sizeOriginal          1.000000  0.601895        0.309867      0.736764
# sizeDaff              0.601895  1.000000        0.614369      0.601267
# comparisonTime        0.309867  0.614369        1.000000      0.673600
# patchingTime          0.736764  0.601267        0.673600      1.000000
# validationTime        0.606746  0.461191        0.650051      0.899186
# numberOfVersions      0.211082  0.057345        0.002491      0.041196
# originalRows          0.575585  0.513321        0.715613      0.858356
# originalColumns       0.307978  0.147851        0.014711      0.150050
# addedRows             0.185819  0.015700        0.014075      0.033975
# deletedRows          -0.041976  0.030003       -0.003592     -0.044472
# modifiedRows          0.064123  0.193062        0.012559      0.018690
# addedColumns         -0.192488 -0.070666       -0.039880     -0.111472
# deletedColumns       -0.191876 -0.070263       -0.039582     -0.111033
# changedCells          0.023991  0.135460        0.008486     -0.000194
# difference           -0.269354  0.078962        0.029396     -0.111010
#
#                   validationTime  numberOfVersions  originalRows  \
# sizeOriginal            0.606746          0.211082      0.575585
# sizeDaff                0.461191          0.057345      0.513321
# comparisonTime          0.650051          0.002491      0.715613
# patchingTime            0.899186          0.041196      0.858356
# validationTime          1.000000          0.028414      0.897107
# numberOfVersions        0.028414          1.000000     -0.026719
# originalRows            0.897107         -0.026719      1.000000
# originalColumns         0.019302         -0.145132      0.043883
# addedRows               0.192013          0.011350     -0.021198
# deletedRows             0.010118          0.012585     -0.084322
# modifiedRows           -0.000430         -0.012150     -0.011815
# addedColumns           -0.074580          0.089511     -0.103819
# deletedColumns         -0.073900          0.092116     -0.103085
# changedCells            0.000277         -0.002025     -0.012473
# difference             -0.086417          0.106132     -0.133822
#
#                   originalColumns  addedRows  deletedRows  modifiedRows  \
# sizeOriginal             0.307978   0.185819    -0.041976      0.064123
# sizeDaff                 0.147851   0.015700     0.030003      0.193062
# comparisonTime           0.014711   0.014075    -0.003592      0.012559
# patchingTime             0.150050   0.033975    -0.044472      0.018690
# validationTime           0.019302   0.192013     0.010118     -0.000430
# numberOfVersions        -0.145132   0.011350     0.012585     -0.012150
# originalRows             0.043883  -0.021198    -0.084322     -0.011815
# originalColumns          1.000000  -0.043428    -0.198751      0.094559
# addedRows               -0.043428   1.000000     0.162704      0.001675
# deletedRows             -0.198751   0.162704     1.000000     -0.011578
# modifiedRows             0.094559   0.001675    -0.011578      1.000000
# addedColumns            -0.371227  -0.011880     0.172549     -0.048025
# deletedColumns          -0.375661  -0.011504     0.173568     -0.050873
# changedCells            -0.010943   0.008005     0.062149      0.908867
# difference              -0.466477  -0.045134     0.135436      0.076506
#
#                   addedColumns  deletedColumns  changedCells  difference
# sizeOriginal         -0.192488       -0.191876      0.023991   -0.269354
# sizeDaff             -0.070666       -0.070263      0.135460    0.078962
# comparisonTime       -0.039880       -0.039582      0.008486    0.029396
# patchingTime         -0.111472       -0.111033     -0.000194   -0.111010
# validationTime       -0.074580       -0.073900      0.000277   -0.086417
# numberOfVersions      0.089511        0.092116     -0.002025    0.106132
# originalRows         -0.103819       -0.103085     -0.012473   -0.133822
# originalColumns      -0.371227       -0.375661     -0.010943   -0.466477
# addedRows            -0.011880       -0.011504      0.008005   -0.045134
# deletedRows           0.172549        0.173568      0.062149    0.135436
# modifiedRows         -0.048025       -0.050873      0.908867    0.076506
# addedColumns          1.000000        0.999781      0.000011    0.605171
# deletedColumns        0.999781        1.000000     -0.002811    0.607040
# changedCells          0.000011       -0.002811      1.000000    0.098860
# difference            0.605171        0.607040      0.098860    1.000000

# %%
sns.set(style="white")
corr = df.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
sns.plt.show()

# %%
dfTest = df.ix[:,6:15]

# %%
dfTest.describe()
# Out:
#        originalRows  originalColumns   addedRows  deletedRows  modifiedRows  \
# count    726.000000       726.000000  726.000000   726.000000    726.000000
# mean     431.234160         5.404959    1.852942     0.792824      0.088197
# std     1596.233829         8.479829   21.371108     2.021257      0.802850
# min        1.000000         1.000000    0.000000     0.000000      0.000000
# 25%       24.000000         1.000000    0.028640     0.008388      0.000000
# 50%       74.000000         1.000000    0.220709     0.209025      0.000000
# 75%      455.000000         6.000000    0.771335     0.523821      0.003696
# max    29225.000000        51.000000  572.250000    31.408696     19.774510
#
#        addedColumns  deletedColumns   changedCells  difference
# count    726.000000      726.000000     726.000000  726.000000
# mean       0.225498        0.224304    1663.955061    0.744244
# std        0.286035        0.286892   29564.600994    0.458238
# min        0.000000        0.000000       0.000545    0.018294
# 25%        0.009259        0.000000       3.746759    0.329529
# 50%        0.229021        0.229021     100.296340    0.730028
# 75%        0.362727        0.362727     361.371122    1.058944
# max        6.187500        6.187500  795793.332881    3.684918

# %%
dfTest2 = dfTest

# %%
dfTest2.head()
# Out:
#         originalRows  originalColumns  addedRows  deletedRows  modifiedRows  \
# folder
# 31              1320                2   0.005097     0.000008      0.000634
# 74                18               12   0.005892     0.001684      1.194444
# 98              1858               18   0.000951     0.000048      0.023643
# 516              157               22   0.009099     0.001365      0.000000
# 519               64               13   0.154830     0.008168      0.067827
#
#         addedColumns  deletedColumns  changedCells  difference
# folder
# 31          0.000000        0.000000      0.005422    0.018294
# 74          0.002525        0.002525    114.413931    0.993927
# 98          0.001984        0.000000      7.818300    0.063042
# 516         0.000000        0.000000      0.010299    0.106635
# 519         0.000000        0.000000      0.169744    0.088475

# %%
dfTest2['schema'] = "same"

# %%
df['schema'] = "different"

# %%
df.loc[df.deletedColumns + df.addedColumns == 0,  'schema'] = 'same'

# %%
df.head()
# Out:
#         sizeOriginal  sizeDaff  comparisonTime  patchingTime  validationTime  \
# folder
# 31           6936693    126897            3896         10388            3840
# 74            166816    165803             152           109             106
# 98          14609270    921000           20471        237332           10327
# 516          5524334    589086            2023         10137            1452
# 519          3235981    286304            1292          6907             811
#
#         numberOfVersions  originalRows  originalColumns  addedRows  \
# folder
# 31                    92          1320                2   0.005097
# 74                    66            18               12   0.005892
# 98                    56          1858               18   0.000951
# 516                   42           157               22   0.009099
# 519                   44            64               13   0.154830
#
#         deletedRows  modifiedRows  addedColumns  deletedColumns  changedCells  \
# folder
# 31         0.000008      0.000634      0.000000        0.000000      0.005422
# 74         0.001684      1.194444      0.002525        0.002525    114.413931
# 98         0.000048      0.023643      0.001984        0.000000      7.818300
# 516        0.001365      0.000000      0.000000        0.000000      0.010299
# 519        0.008168      0.067827      0.000000        0.000000      0.169744
#
#         difference     schema
# folder
# 31        0.018294       same
# 74        0.993927  different
# 98        0.063042  different
# 516       0.106635       same
# 519       0.088475       same

# %%
dfTest2.head()
# Out:
#         originalRows  originalColumns  addedRows  deletedRows  modifiedRows  \
# folder
# 31              1320                2   0.005097     0.000008      0.000634
# 74                18               12   0.005892     0.001684      1.194444
# 98              1858               18   0.000951     0.000048      0.023643
# 516              157               22   0.009099     0.001365      0.000000
# 519               64               13   0.154830     0.008168      0.067827
#
#         addedColumns  deletedColumns  changedCells  difference schema
# folder
# 31          0.000000        0.000000      0.005422    0.018294   same
# 74          0.002525        0.002525    114.413931    0.993927   same
# 98          0.001984        0.000000      7.818300    0.063042   same
# 516         0.000000        0.000000      0.010299    0.106635   same
# 519         0.000000        0.000000      0.169744    0.088475   same

# %%
df.plot(kind='scatter', x='addedColumns', y='deletedColumns');

# %%
dfTest2 = df[[6,7,10,11,12,13,14,15]]

# %%
dfTest2.head()
# Out:
#         originalRows  originalColumns  modifiedRows  addedColumns  \
# folder
# 31              1320                2      0.000634      0.000000
# 74                18               12      1.194444      0.002525
# 98              1858               18      0.023643      0.001984
# 516              157               22      0.000000      0.000000
# 519               64               13      0.067827      0.000000
#
#         deletedColumns  changedCells  difference     schema
# folder
# 31            0.000000      0.005422    0.018294       same
# 74            0.002525    114.413931    0.993927  different
# 98            0.000000      7.818300    0.063042  different
# 516           0.000000      0.010299    0.106635       same
# 519           0.000000      0.169744    0.088475       same

# %%
g = sns.pairplot(dfTest2, hue='schema')
sns.plt.show()

# %%
dfSameSchema = df.loc[df['addedColumns'] == 0].loc[df['deletedColumns'] == 0]
sns.set(style="white")
corr = dfSameSchema.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

sns.plt.show()

# %%
dfChangeSchema = df.loc[df['addedColumns'] != 0].loc[df['deletedColumns'] != 0]
sns.set(style="white")
corr = dfChangeSchema.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
sns.plt.show()

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(dfBox, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-b3de7da37f3c> in <module>()
#       1 from pandas.tools.plotting import scatter_matrix
# ----> 2 scatter_matrix(dfBox, alpha=0.2, figsize=(6, 6), diagonal='kde')
#
# NameError: name 'dfBox' is not defined

# %%
df.head()
# Out:
#         sizeOriginal  sizeDaff  comparisonTime  patchingTime  validationTime  \
# folder
# 31           6936693    126897            3896         10388            3840
# 74            166816    165803             152           109             106
# 98          14609270    921000           20471        237332           10327
# 516          5524334    589086            2023         10137            1452
# 519          3235981    286304            1292          6907             811
#
#         numberOfVersions  originalRows  originalColumns  addedRows  \
# folder
# 31                    92          1320                2   0.005097
# 74                    66            18               12   0.005892
# 98                    56          1858               18   0.000951
# 516                   42           157               22   0.009099
# 519                   44            64               13   0.154830
#
#         deletedRows  modifiedRows  addedColumns  deletedColumns  changedCells  \
# folder
# 31         0.000008      0.000634      0.000000        0.000000      0.005422
# 74         0.001684      1.194444      0.002525        0.002525    114.413931
# 98         0.000048      0.023643      0.001984        0.000000      7.818300
# 516        0.001365      0.000000      0.000000        0.000000      0.010299
# 519        0.008168      0.067827      0.000000        0.000000      0.169744
#
#         difference     schema
# folder
# 31        0.018294       same
# 74        0.993927  different
# 98        0.063042  different
# 516       0.106635       same
# 519       0.088475       same

# %%
import re
label = ""
for index, row in df.iterrows():
    if (row['addedColumns'] == 0 and row['deletedColumns'] == 0):
        label = "same"
    else:
        label = "different"
    df.set_value(index, 'schema', label) 
df.head()
# Out:
#         sizeOriginal  sizeDaff  comparisonTime  patchingTime  validationTime  \
# folder
# 31           6936693    126897            3896         10388            3840
# 74            166816    165803             152           109             106
# 98          14609270    921000           20471        237332           10327
# 516          5524334    589086            2023         10137            1452
# 519          3235981    286304            1292          6907             811
#
#         numberOfVersions  originalRows  originalColumns  addedRows  \
# folder
# 31                    92          1320                2   0.005097
# 74                    66            18               12   0.005892
# 98                    56          1858               18   0.000951
# 516                   42           157               22   0.009099
# 519                   44            64               13   0.154830
#
#         deletedRows  modifiedRows  addedColumns  deletedColumns  changedCells  \
# folder
# 31         0.000008      0.000634      0.000000        0.000000      0.005422
# 74         0.001684      1.194444      0.002525        0.002525    114.413931
# 98         0.000048      0.023643      0.001984        0.000000      7.818300
# 516        0.001365      0.000000      0.000000        0.000000      0.010299
# 519        0.008168      0.067827      0.000000        0.000000      0.169744
#
#         difference     schema
# folder
# 31        0.018294       same
# 74        0.993927  different
# 98        0.063042  different
# 516       0.106635       same
# 519       0.088475       same

# %%
df.head()
# Out:
#         sizeOriginal  sizeDaff  comparisonTime  patchingTime  validationTime  \
# folder
# 31           6936693    126897            3896         10388            3840
# 74            166816    165803             152           109             106
# 98          14609270    921000           20471        237332           10327
# 516          5524334    589086            2023         10137            1452
# 519          3235981    286304            1292          6907             811
#
#         numberOfVersions  originalRows  originalColumns  addedRows  \
# folder
# 31                    92          1320                2   0.005097
# 74                    66            18               12   0.005892
# 98                    56          1858               18   0.000951
# 516                   42           157               22   0.009099
# 519                   44            64               13   0.154830
#
#         deletedRows  modifiedRows  addedColumns  deletedColumns  changedCells  \
# folder
# 31         0.000008      0.000634      0.000000        0.000000      0.005422
# 74         0.001684      1.194444      0.002525        0.002525    114.413931
# 98         0.000048      0.023643      0.001984        0.000000      7.818300
# 516        0.001365      0.000000      0.000000        0.000000      0.010299
# 519        0.008168      0.067827      0.000000        0.000000      0.169744
#
#         difference     schema
# folder
# 31        0.018294       same
# 74        0.993927  different
# 98        0.063042  different
# 516       0.106635       same
# 519       0.088475       same

# %%
dfTest = df.copy()

# %%
dfTest['averageSize'] = dfTest['sizeOriginal'] / dfTest['numberOfVersions']
dfTest['averageDaff'] = dfTest['sizeDaff'] / dfTest['numberOfVersions']
dfTest['sizeDifference'] = (dfTest['sizeOriginal'] - dfTest['sizeDaff'])
dfTest['averageDifference'] = dfTest['sizeDifference'] / dfTest['numberOfVersions']
dfTest['averageRatio'] = dfTest['averageDaff'] / dfTest['averageSize']

# %%
dfTest.head()
# Out:
#         sizeOriginal  sizeDaff  comparisonTime  patchingTime  validationTime  \
# folder
# 31           6936693    126897            3896         10388            3840
# 74            166816    165803             152           109             106
# 98          14609270    921000           20471        237332           10327
# 516          5524334    589086            2023         10137            1452
# 519          3235981    286304            1292          6907             811
#
#         numberOfVersions  originalRows  originalColumns  addedRows  \
# folder
# 31                    92          1320                2   0.005097
# 74                    66            18               12   0.005892
# 98                    56          1858               18   0.000951
# 516                   42           157               22   0.009099
# 519                   44            64               13   0.154830
#
#         deletedRows      ...       addedColumns  deletedColumns  changedCells  \
# folder                   ...
# 31         0.000008      ...           0.000000        0.000000      0.005422
# 74         0.001684      ...           0.002525        0.002525    114.413931
# 98         0.000048      ...           0.001984        0.000000      7.818300
# 516        0.001365      ...           0.000000        0.000000      0.010299
# 519        0.008168      ...           0.000000        0.000000      0.169744
#
#         difference     schema    averageSize   averageDaff  sizeDifference  \
# folder
# 31        0.018294       same   75398.836957   1379.315217         6809796
# 74        0.993927  different    2527.515152   2512.166667            1013
# 98        0.063042  different  260879.821429  16446.428571        13688270
# 516       0.106635       same  131531.761905  14025.857143         4935248
# 519       0.088475       same   73545.022727   6506.909091         2949677
#
#         averageDifference  averageRatio
# folder
# 31           74019.521739      0.018294
# 74              15.348485      0.993927
# 98          244433.392857      0.063042
# 516         117505.904762      0.106635
# 519          67038.113636      0.088475
#
# [5 rows x 21 columns]

# %%
dfTest.sizeDifference.hist()
plt.show()

# %%
dfTest.averageDifference.plot.hist()
plt.show()

# %%
import seaborn
seaborn.set(style='ticks')

fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(dfTest['averageSize'], bins=20)
b_heights, b_bins = np.histogram(dfTest['averageDaff'], bins=a_bins)

width = (a_bins[1] - a_bins[0])/3

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue', label="averageSize")
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen', label="averageDaff")
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)
seaborn.despine(ax=ax, offset=10)
sns.plt.xlabel('Size in bytes')
sns.plt.ylabel('n')
sns.plt.savefig("pictures/averageSize.pdf")
sns.plt.show()

# %%
seaborn.set(style='ticks')

fig, ax = plt.subplots()

heights, bins = np.histogram(dfTest['averageRatio'], bins=40)

width = (bins[1] - bins[0])

ax.bar(bins[:-1], heights, width=width, facecolor='cornflowerblue', label="ratio")
handles, labels = ax.get_legend_handles_labels()

ax.legend(handles, labels)
seaborn.despine(ax=ax, offset=10)
sns.plt.xlabel('Size of Daff/Size of Original')
sns.plt.ylabel('n')
sns.plt.savefig("pictures/ratioDifference.pdf")
sns.plt.show()

# %%
sns.distplot(dfTest['averageComparison']);
sns.plt.xlabel('Time in milliseconds')
sns.plt.ylabel('n')
sns.plt.show()
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
dfTest['averageComparison'] = dfTest['comparisonTime'] / dfTest['numberOfVersions']
dfTest['averagePatching'] = dfTest['patchingTime'] / dfTest['numberOfVersions']
dfTest['averageValidation'] = dfTest['validationTime'] / dfTest['numberOfVersions']

# %%
import seaborn
seaborn.set(style='ticks')

fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(dfTest['averageComparison'], bins=20)
b_heights, b_bins = np.histogram(dfTest['averagePatching'], bins=a_bins)
c_heights, c_bins = np.histogram(dfTest['averageValidation'], bins=a_bins)

width = (a_bins[1] - a_bins[0])/4

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue', label="daffTime")
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen', label="patchingTime")
ax.bar(c_bins[:-1]+2*width, c_heights, width=width, facecolor='orangered', label="validationTime")

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)
seaborn.despine(ax=ax, offset=10)
sns.plt.xlabel('Time in milliseconds')
sns.plt.ylabel('n')
sns.plt.savefig("pictures/timeDistribution.pdf")
sns.plt.show()

# %%
dfTest.describe()
# Out:
#        sizeOriginal  comparisonTime  patchingTime  validationTime  \
# count  7.260000e+02    7.260000e+02  7.260000e+02      726.000000
# mean   7.080259e+05    6.247583e+03  8.964331e+03     1190.757576
# std    1.904106e+06    9.996206e+04  6.105751e+04     7186.780706
# min    4.940000e+02    6.000000e+00  5.000000e+00        4.000000
# 25%    7.775675e+04    3.117500e+02  6.325000e+01      167.250000
# 50%    1.864425e+05    6.730000e+02  1.320000e+02      324.000000
# 75%    3.836960e+05    1.106000e+03  3.197500e+02      535.750000
# max    1.889952e+07    2.676666e+06  1.005401e+06   123843.000000
#
#        numberOfVersions  originalRows  originalColumns   addedRows  \
# count        726.000000    726.000000       726.000000  726.000000
# mean          17.826446    431.234160         5.404959    1.852942
# std            6.179848   1596.233829         8.479829   21.371108
# min            8.000000      1.000000         1.000000    0.000000
# 25%           14.000000     24.000000         1.000000    0.028640
# 50%           18.000000     74.000000         1.000000    0.220709
# 75%           21.000000    455.000000         6.000000    0.771335
# max           92.000000  29225.000000        51.000000  572.250000
#
#        deletedRows  modifiedRows        ...           changedCells  \
# count   726.000000    726.000000        ...             726.000000
# mean      0.792824      0.088197        ...            1663.955061
# std       2.021257      0.802850        ...           29564.600994
# min       0.000000      0.000000        ...               0.000545
# 25%       0.008388      0.000000        ...               3.746759
# 50%       0.209025      0.000000        ...             100.296340
# 75%       0.523821      0.003696        ...             361.371122
# max      31.408696     19.774510        ...          795793.332881
#
#        difference    averageSize    averageDaff  sizeDifference  \
# count  726.000000     726.000000     726.000000    7.260000e+02
# mean     0.744244   39951.069432   16939.287271    4.157782e+05
# std      0.458238   97569.200191   51290.988392    1.530305e+06
# min      0.018294      19.000000      41.115385   -5.356349e+06
# 25%      0.329529    4189.005013    3653.739583   -3.773500e+03
# 50%      0.730028   11580.639706    6324.330357    3.597400e+04
# 75%      1.058944   23219.762363   12183.635870    1.603665e+05
# max      3.684918  833930.047619  837147.470588    1.620323e+07
#
#        averageDifference  averageRatio  averageComparison  averagePatching  \
# count         726.000000    726.000000         726.000000       726.000000
# mean        23011.782161      0.744244         361.479476       530.344862
# std         77595.228227      0.458238        5870.770890      3745.105092
# min       -243470.409091      0.018294           0.500000         0.384615
# 25%          -218.937500      0.329529          17.376488         3.892534
# 50%          2295.355263      0.730028          37.103679         7.302174
# 75%         10236.473077      1.058944          59.813939        21.000000
# max        771582.238095      3.684918      157450.941176     59141.235294
#
#        averageValidation
# count         726.000000
# mean           69.796603
# std           432.485684
# min             0.409091
# 25%             9.308333
# 50%            18.623737
# 75%            28.869444
# max          6815.705882
#
# [8 rows x 22 columns]

# %%
df[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0)].sizeOriginal.hist()
plt.show()

# %%
df[(df['addedColumns'] != 0) & (df['deletedColumns'] !=0)].sizeOriginal.hist(bins=10)
plt.show()

# %%
df[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0) & (df['addedRows'] == 0) & (df['deletedRows'] ==0)]
# Out:
#         sizeOriginal  sizeDaff  evolution  patch  quality  numberOfVersions  \
# folder
# 5171          514216    327327        355    526      140                18
# 5540         6309842   2920815      17596  93027     2539                17
# 5680          380841     90369        125    370       88                15
# 5847          610788    443814        623    934      157                14
# 5933            3853      5616         12      9        7                16
# 6273          705771    708261       2952   1979     2271                12
# 6528            4354      6188         20     13        7                11
# 6618          563381     81136        177    914      126                11
# 6798            2658      4082          7      7        7                11
# 7001           14250      4336         20     13       15                10
#
#         originalRows  originalColumns  addedRows  deletedRows  modifiedRows  \
# folder
# 5171             214               10        0.0          0.0      0.944444
# 5540             732               44        0.0          0.0      0.941176
# 5680              69               32        0.0          0.0      0.333333
# 5847             310               11        0.0          0.0      0.928571
# 5933               4                4        0.0          0.0      0.875000
# 6273               9                4        0.0          0.0      0.916667
# 6528              14                3        0.0          0.0      0.902597
# 6618             280               14        0.0          0.0      0.090260
# 6798               4                4        0.0          0.0      0.909091
# 7001               3               36        0.0          0.0      0.900000
#
#         addedColumns  deletedColumns  changedCells  difference schema
# folder
# 5171             0.0             0.0      0.105607    0.636555   same
# 5540             0.0             0.0      0.025839    0.462898   same
# 5680             0.0             0.0      0.012107    0.237288   same
# 5847             0.0             0.0      0.090930    0.726625   same
# 5933             0.0             0.0      0.578125    1.457566   same
# 6273             0.0             0.0      0.250000    1.003528   same
# 6528             0.0             0.0      0.461039    1.421222   same
# 6618             0.0             0.0      0.012894    0.144016   same
# 6798             0.0             0.0      0.602273    1.535741   same
# 7001             0.0             0.0      0.030556    0.304281   same

# %%
df[  (df['deletedColumns'] ==0)  & (df['deletedRows'] ==0)].describe()
# Out:
#        sizeOriginal      sizeDaff     evolution         patch       quality  \
# count  8.100000e+01  8.100000e+01     81.000000     81.000000     81.000000
# mean   6.252711e+05  1.236520e+05    757.530864   2937.555556    465.876543
# std    1.212944e+06  3.382019e+05   2380.409540  11227.547277   1466.072119
# min    2.658000e+03  1.680000e+03      7.000000      7.000000      7.000000
# 25%    6.957900e+04  1.589400e+04     39.000000     44.000000     29.000000
# 50%    1.814990e+05  4.324700e+04     90.000000    248.000000     64.000000
# 75%    6.107880e+05  9.643000e+04    306.000000    895.000000    173.000000
# max    6.309842e+06  2.920815e+06  17596.000000  93027.000000  10403.000000
#
#        numberOfVersions  originalRows  originalColumns  addedRows  \
# count         81.000000     81.000000        81.000000  81.000000
# mean          14.506173    361.024691        13.864198   0.127034
# std            5.415541    886.117134         7.971438   0.975086
# min            9.000000      3.000000         1.000000   0.000000
# 25%           11.000000     51.000000         6.000000   0.000978
# 50%           13.000000    116.000000        18.000000   0.004843
# 75%           17.000000    201.000000        18.000000   0.017921
# max           42.000000   5185.000000        44.000000   8.785714
#
#        deletedRows  modifiedRows  addedColumns  deletedColumns  changedCells  \
# count         81.0     81.000000     81.000000            81.0     81.000000
# mean           0.0      0.275615      0.006060             0.0      3.219438
# std            0.0      0.893576      0.014662             0.0     11.461677
# min            0.0      0.000000      0.000000             0.0      0.000545
# 25%            0.0      0.010581      0.000000             0.0      0.021848
# 50%            0.0      0.099167      0.004630             0.0      1.514757
# 75%            0.0      0.159314      0.009259             0.0      3.247848
# max            0.0      7.828571      0.129870             0.0    102.810967
#
#        difference
# count   81.000000
# mean     0.293010
# std      0.284993
# min      0.045004
# 25%      0.124443
# 50%      0.225767
# 75%      0.309848
# max      1.535741

# %%
dfCorr = dfTest.copy()

# %%
dfCorr.head()
# Out:
#         sizeOriginal  comparisonTime  patchingTime  validationTime  \
# folder
# 31           6936693            3896         10388            3840
# 74            166816             152           109             106
# 98          14609270           20471        237332           10327
# 516          5524334            2023         10137            1452
# 519          3235981            1292          6907             811
#
#         numberOfVersions  originalRows  originalColumns  addedRows  \
# folder
# 31                    92          1320                2   0.005097
# 74                    66            18               12   0.005892
# 98                    56          1858               18   0.000951
# 516                   42           157               22   0.009099
# 519                   44            64               13   0.154830
#
#         deletedRows  modifiedRows        ...          difference     schema  \
# folder                                   ...
# 31         0.000008      0.000634        ...            0.018294       same
# 74         0.001684      1.194444        ...            0.993927  different
# 98         0.000048      0.023643        ...            0.063042  different
# 516        0.001365      0.000000        ...            0.106635       same
# 519        0.008168      0.067827        ...            0.088475       same
#
#           averageSize   averageDaff sizeDifference  averageDifference  \
# folder
# 31       75398.836957   1379.315217        6809796       74019.521739
# 74        2527.515152   2512.166667           1013          15.348485
# 98      260879.821429  16446.428571       13688270      244433.392857
# 516     131531.761905  14025.857143        4935248      117505.904762
# 519      73545.022727   6506.909091        2949677       67038.113636
#
#         averageRatio  averageComparison  averagePatching  averageValidation
# folder
# 31          0.018294          42.347826       112.913043          41.739130
# 74          0.993927           2.303030         1.651515           1.606061
# 98          0.063042         365.553571      4238.071429         184.410714
# 516         0.106635          48.166667       241.357143          34.571429
# 519         0.088475          29.363636       156.977273          18.431818
#
# [5 rows x 23 columns]

# %%
del dfCorr['sizeOriginal']
del dfCorr['sizeDifference']
del dfCorr['comparisonTime']
del dfCorr['patchingTime']
del dfCorr['validationTime']
del dfCorr['difference']

# %%
df[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0)]

# %%
sns.set(style="white")
corr = dfCorr.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax, annot_kws={"size":20})
sns.plt.savefig("pictures/correlation.pdf")
sns.plt.show()

# %%
g = sns.pairplot(dfCorr,vars=["addedColumns", "deletedColumns"])
sns.plt.savefig("pictures/addedDeleted.pdf")

sns.plt.show()

# %%
dfCorr[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0) & (df['addedRows'] == 0) & (df['deletedRows'] ==0)].count()
# Out:
# numberOfVersions     10
# originalRows         10
# originalColumns      10
# addedRows            10
# deletedRows          10
# modifiedRows         10
# addedColumns         10
# deletedColumns       10
# changedCells         10
# schema               10
# averageSize          10
# averageDaff          10
# averageDifference    10
# averageRatio         10
# averageComparison    10
# averagePatching      10
# averageValidation    10
# dtype: int64

# %%
#STATIC
sns.set(style="white")
corr = dfCorr[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0) & (df['addedRows'] == 0) & (df['deletedRows'] ==0)].corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
sns.plt.show()

# %%
g = sns.pairplot(dfCorr[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0) & (df['addedRows'] == 0) & (df['deletedRows'] ==0)],x_vars=["averageSize", "averageDaff"],y_vars=["averageDaff", "averageDifference"] )
sns.plt.show()

# %%
dfCorr[ (df['deletedColumns'] ==0) & ((df['addedRows'] > 0) | (df['addedColumns'] > 0))  & (df['deletedRows'] ==0)].count()
# Out:
# numberOfVersions     71
# originalRows         71
# originalColumns      71
# addedRows            71
# deletedRows          71
# modifiedRows         71
# addedColumns         71
# deletedColumns       71
# changedCells         71
# schema               71
# averageSize          71
# averageDaff          71
# averageDifference    71
# averageRatio         71
# averageComparison    71
# averagePatching      71
# averageValidation    71
# dtype: int64

# %%
#INCREASING
sns.set(style="white")
corr = dfCorr[ (df['deletedColumns'] ==0) & ((df['addedRows'] > 0) | (df['addedColumns'] > 0))  & (df['deletedRows'] ==0)].corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
sns.plt.show()

# %%
g = sns.pairplot(dfCorr[ (df['deletedColumns'] ==0) & ((df['addedRows'] > 0) | (df['addedColumns'] > 0))  & (df['deletedRows'] ==0)] ,vars=["averageSize", "averageDifference"] )
g.set(xticklabels=[])
g.set(yticklabels=[])
sns.plt.savefig("pictures/increasing1.pdf")
sns.plt.show()

# %%
g = sns.pairplot(dfCorr[ (df['deletedColumns'] ==0) & ((df['addedRows'] > 0) | (df['addedColumns'] > 0))  & (df['deletedRows'] ==0)] ,vars=["modifiedRows", "addedRows"] )
g.set(xticklabels=[])
g.set(yticklabels=[])
sns.plt.savefig("pictures/increasing2.pdf")
sns.plt.show()

# %%
g = sns.pairplot(dfCorr[ (df['deletedColumns'] ==0) & ((df['addedRows'] > 0) | (df['addedColumns'] > 0))  & (df['deletedRows'] ==0)] ,x_vars=["averageSize", "modifiedRows"],y_vars=["modifiedRows", "averageDifference"] )
sns.plt.show()

# %%
dfCorr[ (df['addedRows'] ==0) & ((df['deletedColumns'] > 0) | (df['deletedRows'] > 0))  & (df['addedColumns'] ==0)]
# Out:
#         numberOfVersions  originalRows  originalColumns  addedRows  \
# folder
# 6214                  11           133               32        0.0
# 6410                  12          3441               14        0.0
#
#         deletedRows  modifiedRows  addedColumns  deletedColumns  changedCells  \
# folder
# 6214       0.002734      0.611757           0.0             0.0      0.021852
# 6410       0.000024      0.083285           0.0             0.0      0.012903
#
#        schema    averageSize   averageDaff  averageDifference  averageRatio  \
# folder
# 6214     same   49627.181818  17104.272727       32522.909091      0.344655
# 6410     same  402426.916667  74995.833333      327431.083333      0.186359
#
#         averageComparison  averagePatching  averageValidation
# folder
# 6214            41.454545       144.000000          26.000000
# 6410          1588.916667     10459.583333         482.166667

# %%
#SAME SCHEMA
sns.set(style="white")
corr = dfCorr[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0) & ((df['addedRows'] > 0) | (df['deletedRows'] >0))].corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
sns.plt.show()

# %%
g = sns.pairplot(dfCorr[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0) & ((df['addedRows'] > 0) | (df['deletedRows'] >0))] ,vars=["addedRows", "deletedRows"] )
sns.plt.savefig("pictures/sameschema1.pdf")
sns.plt.show()

# %%
g = sns.pairplot(dfCorr[(df['addedRows'] < 8) & (df['addedColumns'] == 0) & (df['deletedColumns'] ==0) & ((df['addedRows'] > 0) | (df['deletedRows'] >0))] ,vars=["addedRows", "deletedRows"] )
sns.plt.savefig("pictures/sameschema2.pdf")
sns.plt.show()

# %%
dfCorr[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0) & ((df['addedRows'] > 0) | (df['deletedRows'] >0))].count()
# Out:
# numberOfVersions     107
# originalRows         107
# originalColumns      107
# addedRows            107
# deletedRows          107
# modifiedRows         107
# addedColumns         107
# deletedColumns       107
# changedCells         107
# schema               107
# averageSize          107
# averageDaff          107
# averageDifference    107
# averageRatio         107
# averageComparison    107
# averagePatching      107
# averageValidation    107
# dtype: int64

# %%
dfCorr[((df['addedColumns'] > 0) | (df['deletedColumns'] >0)) & (df['addedRows'] == 0) & (df['deletedRows'] ==0)].count()
# Out:
# numberOfVersions     9
# originalRows         9
# originalColumns      9
# addedRows            9
# deletedRows          9
# modifiedRows         9
# addedColumns         9
# deletedColumns       9
# changedCells         9
# schema               9
# averageSize          9
# averageDaff          9
# averageDifference    9
# averageRatio         9
# averageComparison    9
# averagePatching      9
# averageValidation    9
# dtype: int64

# %%
dfCorr[((df['addedColumns'] > 0) | (df['deletedColumns'] >0)) & ((df['addedRows'] > 0) | (df['deletedRows'] > 0))].count()
# Out:
# numberOfVersions     600
# originalRows         600
# originalColumns      600
# addedRows            600
# deletedRows          600
# modifiedRows         600
# addedColumns         600
# deletedColumns       600
# changedCells         600
# schema               600
# averageSize          600
# averageDaff          600
# averageDifference    600
# averageRatio         600
# averageComparison    600
# averagePatching      600
# averageValidation    600
# dtype: int64

# %%
g = sns.pairplot(dfCorr,vars=["changedCells", "modifiedRows"])
sns.plt.show()

# %%
#SAME SCHEMA

sns.set(style="white")
corr = dfCorr[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0)].corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
sns.plt.show()

# %%
#STATIC

sns.set(style="white")
corr = dfCorr[(df['addedColumns'] == 0) & (df['deletedColumns'] ==0) & (df['addedRows'] == 0) & (df['deletedRows'] ==0)].corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
sns.plt.show()

# %%
##GROWING

sns.set(style="white")
corr = dfCorr[(df['addedColumns'] >= 0) & (df['deletedColumns'] ==0) & (df['addedRows'] >= 0) & (df['deletedRows'] ==0)].corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
sns.plt.show()

# %%
##SHRINKING

sns.set(style="white")
corr = dfCorr[(df['addedColumns'] == 0) & (df['deletedColumns'] >= 0) & (df['addedRows'] == 0) & (df['deletedRows']  >= 0)].corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
sns.plt.show()
